# %%
import cv2
from google.colab.patches import cv2_imshow
import os

# %%
# !git clone https://github.com/ntkhang2003/kalapa-vietnamese-handwritten
# Out:
# Cloning into 'kalapa-vietnamese-handwritten'...
# remote: Enumerating objects: 785, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 785 (delta 25), reused 153 (delta 16), pack-reused 621
# Receiving objects: 100% (785/785), 155.03 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# Updating files: 100% (664/664), done.

# %%
# !pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=44413709f2a9650a5636f10d6a448f6493b5a0d1af9ba58bc33e5b2944cd7a86
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# ...

# %%
# %cd /content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator
# Out:
# /content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator

# %% [markdown]
# # 1st level data

# %%
gen_Edata_script = \
'''
dir=1
for file in trdg/fonts/custom/E/*.ttf; do
    python trdg/run.py -c 1 -w 12 -f 128 -l vi -dt dict.txt -ft $file -na 2 --output_dir out/$dir
    dir=$((dir+1))
done
'''
with open('genEdata.sh', 'w') as f:
    f.write(gen_Edata_script)
# !bash genEdata.sh
# Out:
# 2023-12-05 05:12:08.068117: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 05:12:08.068180: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 05:12:08.068221: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 05:12:08.077577: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import shutil
shutil.make_archive('out', 'zip', 'out')
# Out:
# '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out.zip'

# %% [markdown]
# # 2nd level data

# %%
# !rm -r out

# %%
gen_Ddata_script = \
'''
dir=20
for file in trdg/fonts/custom/D/*.ttf; do
    python trdg/run.py -c 1 -w 12 -f 128 -l vi -dt dict.txt -ft $file -na 2 --output_dir out/$dir
    dir=$((dir+1))
done
'''
with open('genDdata.sh', 'w') as f:
    f.write(gen_Ddata_script)
# !bash genDdata.sh
# Out:
# 2023-12-05 14:54:57.938058: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 14:54:57.938130: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 14:54:57.938175: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 14:54:57.948309: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
gen_Ddata_script = \
'''
dir=40
for file in trdg/fonts/custom/D/*.otf; do
    python trdg/run.py -c 1000 -w 12 -f 128 -l vi -dt dict.txt -ft $file -na 2 --output_dir out/$dir
    dir=$((dir+1))
done
'''
with open('genDdata.sh', 'w') as f:
    f.write(gen_Ddata_script)
# !bash genDdata.sh
# Out:
# 2023-11-28 11:30:57.699487: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 11:30:57.699570: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 11:30:57.699608: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 11:30:57.711628: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import shutil
shutil.make_archive('out', 'zip', 'out')
# Out:
# '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out.zip'

# %%
# !zip -r out.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/21'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/20/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out1.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/23'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/22/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out2.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/25'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/24/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out3.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/27'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/26/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out4.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/29'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/28/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out5.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/31'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/30/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out6.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/40'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/32/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out7.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/42'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/41/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out8.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/44'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/43/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out10.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45' '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/46'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/45/792.jpg (deflated 1%)
# ...

# %%
# !zip -r out9.zip '/content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47'
# Out:
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/ (stored 0%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/808.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/393.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/209.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/303.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/60.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/837.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/748.jpg (deflated 1%)
#   adding: content/kalapa-vietnamese-handwritten/TextRecognitionDataGenerator/out/47/792.jpg (deflated 1%)
# ...
